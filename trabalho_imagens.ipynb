# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv2.imread("Glaze.png",0)#O 0 é para colocar a imagem e preto e branco
plt.hist(img.ravel(),256,[0,256])
plt.imshow(img, cmap='gray')

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()# histograma montada

# %%
img=cv2.imread("Glaze.png",0)#limearizão simples
thresh,img_thresh=cv2.threshold(img,195,255,cv2.THRESH_BINARY)
plt.imshow(img_thresh, cmap='gray')
